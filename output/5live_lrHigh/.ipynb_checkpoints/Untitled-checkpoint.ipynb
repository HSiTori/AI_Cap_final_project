# %%
# !ls
import pandas as pd

data = pd.read_csv('output_5wrap_save.txt', header=None)
print(data)
# Out:
# Untitled.ipynb        my_model.h5           output_5wrap_save.txt
#            0         1         2
# 0          0 -4.000000  0.017990
# 1          1 -3.500000  0.035114
# 2          2 -3.666667  0.035852
# 3          3 -4.000000  0.001738
# 4          4 -3.200000  0.033419
# ...      ...       ...       ...
# 10088  10088 -4.000000  0.020063
# 10089  10089 -4.000000  0.017473
# 10090  10090 -4.333333  0.060784
# 10091  10091 -4.166667  0.061724
# 10092  10092 -4.000000  0.243086
#
# [10093 rows x 3 columns]

# %%
len(data)
import numpy as np

x = np.arange(1,len(data))
data.plot()
# Out:
# <AxesSubplot:>
