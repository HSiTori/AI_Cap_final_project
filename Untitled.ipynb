# %%
# !ls
import pandas as pd

data = pd.read_csv('output_5wrap.txt', header=None)
print(data)
# Out:
# README.md              breakout_5wrap.py      output_5wrap.txt
# Untitled.ipynb         breakout_5wrap_save.py
# breakout.py            breakout_delay35.py
#             0
# 0   -5.000000
# 1   -4.000000
# 2   -3.000000
# 3   -3.250000
# 4   -3.200000
# ..        ...
# 642 -3.166667
# 643 -3.833333
# 644 -4.166667
# 645 -4.666667
# 646 -4.666667
#
# [647 rows x 1 columns]

# %%
len(data)
import numpy as np

x = np.arange(1,len(data))
data.plot()
# Out:
# <AxesSubplot:>
